# %% [raw]
# 해당 부분은 교재에 실습 코드가 없어 아래 사이트 참고
# https://bcho.tistory.com/1205

# %% [raw]
# 밀도 기반 군집 분석: 일정 밀도 이상을 가진 데이터를 기준으로 군집을 형성하는 방법
#     k-means clustering과는 달리 사전에 클러스터 숫자를 알지 못할때 사용
#     주어진 데이터에 이상치가 많이 포함되었을 경우 사용하면 좋음
#     k-means clustering보다 연산량은 많지만, k-means clustering이 잘 처리하지 못하는 오목, 볼록한 부분을 처리할 때 유용

# %% [raw]
# 노이즈 vs 이상치
# - 노이즈: 주어진 데이터셋과 무관한 무작위성 데이터 -> 전처리 과정에서 삭제해야함
# - 이상치: 관측된 데이터 범위에서 많이 벗어난 아주 작은 값이나 아주 큰 관측값

# %% [raw]
# 모델 과정
# 1. 엡실론 내 점 개수 확인 및 중심점(p) 결정: 중심점을 기준으로 엡실론 내에 minPts를 충족하는 조건이 되면 군집 설정
#     엡실론: 두 점 사이의 거리로 임계치(범주) 역할
#     minPts: 중심점을 드는 구성 요건, 엡실론 내 데이터 개수
# 2. 군집 확장(여러개로): 주위 점들 중 엡실론 내에 minPts를 충족하는 경우 군집으로 설정, p중심점 설정
# 3. 1~2 단계 반복: 데이터가 밀집된 밀도가 높은 지역에서 더이상 중심점 정의가 안될때까지 반복
# 4. 노이즈 정의: 어떤 군집에도 포함되지 않은 데이터를 노이즈로 정의

# %%
import pandas as pd
from sklearn import datasets

iris = datasets.load_iris()

labels = pd.DataFrame(iris.target)
labels.columns=['labels']
data = pd.DataFrame(iris.data)
data.columns=['Sepal length','Sepal width','Petal length','Petal width']
data = pd.concat([data,labels],axis=1)

data.head()
# Out:
#    Sepal length  Sepal width  Petal length  Petal width  labels
# 0           5.1          3.5           1.4          0.2       0
# 1           4.9          3.0           1.4          0.2       0
# 2           4.7          3.2           1.3          0.2       0
# 3           4.6          3.1           1.5          0.2       0
# 4           5.0          3.6           1.4          0.2       0

# %%
feature = data[ ['Sepal length','Sepal width','Petal length','Petal width']]
feature.head()
# Out:
#    Sepal length  Sepal width  Petal length  Petal width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
from sklearn.cluster import DBSCAN
import matplotlib.pyplot  as plt
import seaborn as sns

# create model and prediction
model = DBSCAN(eps=0.3, min_samples=6)#minPts:min_samples으로 설정, epsilon:eps로 설정
predict = pd.DataFrame(model.fit_predict(feature))
predict.columns=['predict']

# %%
# concatenate labels to df as a new column
r = pd.concat([feature,predict],axis=1)
r
# Out:
#      Sepal length  Sepal width  Petal length  Petal width  predict
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3       -1
# 146           6.3          2.5           5.0          1.9       -1
# 147           6.5          3.0           5.2          2.0       -1
# 148           6.2          3.4           5.4          2.3       -1
# 149           5.9          3.0           5.1          1.8       -1
#
# [150 rows x 5 columns]

# %%
#4차원 데이터를 3차원으로 표현하여 다소 오류 발생한 상태
from mpl_toolkits.mplot3d import Axes3D
# scatter plot
fig = plt.figure( figsize=(6,6))
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
ax.scatter(r['Sepal length'],r['Sepal width'],r['Petal length'],c=r['predict'],alpha=0.5)
ax.set_xlabel('Sepal lenth')
ax.set_ylabel('Sepal width')
ax.set_zlabel('Petal length')
plt.show()
# Out:
# /opt/homebrew/anaconda3/envs/fire_base/lib/python3.7/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   after removing the cwd from sys.path.

# %%
ct = pd.crosstab(data['labels'],r['predict'])
print (ct)
# Out:
# predict  -1   0   1
# labels
# 0        13  37   0
# 1        43   0   7
# 2        50   0   0
